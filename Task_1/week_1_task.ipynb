# %% [markdown]
# ## Question : 1

# %%
if __name__ == '__main__':
    print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## Question : 2

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if n%2 == 1:
        print("Weird")
    elif n%2 == 0:
        if n >= 2 and n <= 5:
            print("Not Weird")
        elif n >= 6 and n <= 20:
            print("Weird")
        elif n >= 20:
            print("Not Weird")
# Out:
#  54
# Not Weird

# %% [markdown]
# ## Question : 3

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    summition = a+b
    subtractin = a-b
    multiplication = a*b
    
    print(summition)
    print(subtractin)
    print(multiplication)
# Out:
#  54
#  63
# 117
# -9
# 3402

# %% [markdown]
# ## Question : 4

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    
    floor_division = a // b
    division = a / b
    
    print(floor_division)
    print(division)
# Out:
#  4
#  6
# 0
# 0.6666666666666666

# %% [markdown]
# ## Question : 5

# %%
if __name__ == '__main__':
    n = int(input())
    
    for i in range(n):
        print(i**2)
# Out:
#  5
# 0
# 1
# 4
# 9
# 16

# %% [markdown]
# ## Question : 6

# %%
def is_leap(year):
    leap = False
    
    if year % 400 == 0:
        leap = True
    elif year % 100 == 0:
        leap = False
    elif year % 4 == 0:
        leap = True
    else:
        leap = False
    return leap

year = int(input())
print(is_leap(year))
# Out:
#  1993
# False

# %% [markdown]
# ## Question : 7

# %%
if __name__ == '__main__':
    n = int(input())
    
    for i in range(1,n+1):
        print(i,end="")
